# %%
import pandas as pd
import numpy as np
data = pd.read_csv('titanic3.csv')

# %%
data.replace('?', np.nan, inplace= True)
data = data.astype({"age": np.float64, "fare": np.float64})

# %%
import seaborn as sns
import matplotlib.pyplot as plt

fig, axs = plt.subplots(ncols=5, figsize=(30,5))
sns.violinplot(x="survived", y="age", hue="sex", data=data, ax=axs[0])
sns.pointplot(x="sibsp", y="survived", hue="sex", data=data, ax=axs[1])
sns.pointplot(x="parch", y="survived", hue="sex", data=data, ax=axs[2])
sns.pointplot(x="pclass", y="survived", hue="sex", data=data, ax=axs[3])
sns.violinplot(x="survived", y="fare", hue="sex", data=data, ax=axs[4])
# Out:
# <AxesSubplot: xlabel='survived', ylabel='fare'>

# %%
data.replace({'male': 1, 'female': 0}, inplace=True)

# %%
data.corr().abs()[["survived"]]
# Out:
# /var/folders/tz/1lqkm97n6wn9ynhk0lcdz8q80000gn/T/ipykernel_3457/143381672.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr().abs()[["survived"]]
#           survived
# pclass    0.312469
# survived  1.000000
# sex       0.528693
# age       0.055512
# sibsp     0.027825
# parch     0.082660
# fare      0.244265
# body           NaN

# %%
data['relatives'] = data.apply (lambda row: int((row['sibsp'] + row['parch']) > 0), axis=1)
data.corr().abs()[["survived"]]
# Out:
# /var/folders/tz/1lqkm97n6wn9ynhk0lcdz8q80000gn/T/ipykernel_3457/3242586923.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr().abs()[["survived"]]
#            survived
# pclass     0.312469
# survived   1.000000
# sex        0.528693
# age        0.055512
# sibsp      0.027825
# parch      0.082660
# fare       0.244265
# body            NaN
# relatives  0.201719

# %%
data = data[['sex', 'pclass','age','relatives','fare','survived']].dropna()

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(data[['sex','pclass','age','relatives','fare']], data.survived, test_size=0.2, random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(x_train)
X_test = sc.transform(x_test)

# %%
from sklearn.naive_bayes import GaussianNB
model = GaussianNB()
model.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
from sklearn import metrics
predict_test = model.predict(X_test)
print(metrics.accuracy_score(y_test, predict_test))
# Out:
# 0.7464114832535885

# %%
from keras.models import Sequential
from keras.layers import Dense

model = Sequential()

# %%
model.add(Dense(5, kernel_initializer = 'uniform', activation = 'relu', input_dim = 5))
model.add(Dense(5, kernel_initializer = 'uniform', activation = 'relu'))
model.add(Dense(1, kernel_initializer = 'uniform', activation = 'sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 5)                 30
#
#  dense_1 (Dense)             (None, 5)                 30
#
#  dense_2 (Dense)             (None, 1)                 6
#
# =================================================================
# Total params: 66
# Trainable params: 66
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer="adam", loss='binary_crossentropy', metrics=['accuracy'])
model.fit(X_train, y_train, batch_size=32, epochs=50)
# Out:
# Epoch 1/50
# 2022-12-19 21:20:11.881631: W tensorflow/tsl/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 27/27 [==============================] - 0s 690us/step - loss: 0.6923 - accuracy: 0.5813
# Epoch 2/50
# 27/27 [==============================] - 0s 654us/step - loss: 0.6905 - accuracy: 0.5861
# Epoch 3/50
# 27/27 [==============================] - 0s 615us/step - loss: 0.6880 - accuracy: 0.5861
# Epoch 4/50
# 27/27 [==============================] - 0s 585us/step - loss: 0.6838 - accuracy: 0.6041
# Epoch 5/50
# 27/27 [==============================] - 0s 567us/step - loss: 0.6768 - accuracy: 0.7189
# Epoch 6/50
# 27/27 [==============================] - 0s 564us/step - loss: 0.6669 - accuracy: 0.7715
# Epoch 7/50
# 27/27 [==============================] - 0s 633us/step - loss: 0.6536 - accuracy: 0.7835
# Epoch 8/50
# 27/27 [==============================] - 0s 539us/step - loss: 0.6388 - accuracy: 0.7679
# Epoch 9/50
# 27/27 [==============================] - 0s 582us/step - loss: 0.6228 - accuracy: 0.7703
# Epoch 10/50
# 27/27 [==============================] - 0s 526us/step - loss: 0.6082 - accuracy: 0.7703
# Epoch 11/50
# 27/27 [==============================] - 0s 525us/step - loss: 0.5942 - accuracy: 0.7715
# Epoch 12/50
# 27/27 [==============================] - 0s 517us/step - loss: 0.5833 - accuracy: 0.7751
# Epoch 13/50
# 27/27 [==============================] - 0s 572us/step - loss: 0.5741 - accuracy: 0.7799
# Epoch 14/50
# 27/27 [==============================] - 0s 575us/step - loss: 0.5664 - accuracy: 0.7775
# Epoch 15/50
# 27/27 [==============================] - 0s 592us/step - loss: 0.5594 - accuracy: 0.7787
# Epoch 16/50
# 27/27 [==============================] - 0s 550us/step - loss: 0.5533 - accuracy: 0.7787
# Epoch 17/50
# 27/27 [==============================] - 0s 579us/step - loss: 0.5479 - accuracy: 0.7775
# Epoch 18/50
# 27/27 [==============================] - 0s 502us/step - loss: 0.5425 - accuracy: 0.7787
# Epoch 19/50
# 27/27 [==============================] - 0s 583us/step - loss: 0.5376 - accuracy: 0.7835
# Epoch 20/50
# 27/27 [==============================] - 0s 547us/step - loss: 0.5332 - accuracy: 0.7799
# Epoch 21/50
# 27/27 [==============================] - 0s 531us/step - loss: 0.5288 - accuracy: 0.7823
# Epoch 22/50
# 27/27 [==============================] - 0s 579us/step - loss: 0.5253 - accuracy: 0.7835
# Epoch 23/50
# 27/27 [==============================] - 0s 643us/step - loss: 0.5210 - accuracy: 0.7847
# Epoch 24/50
# 27/27 [==============================] - 0s 596us/step - loss: 0.5173 - accuracy: 0.7847
# Epoch 25/50
# 27/27 [==============================] - 0s 549us/step - loss: 0.5136 - accuracy: 0.7847
# Epoch 26/50
# 27/27 [==============================] - 0s 551us/step - loss: 0.5103 - accuracy: 0.7823
# Epoch 27/50
# 27/27 [==============================] - 0s 553us/step - loss: 0.5077 - accuracy: 0.7823
# Epoch 28/50
# 27/27 [==============================] - 0s 554us/step - loss: 0.5047 - accuracy: 0.7847
# Epoch 29/50
# 27/27 [==============================] - 0s 551us/step - loss: 0.5019 - accuracy: 0.7835
# Epoch 30/50
# 27/27 [==============================] - 0s 558us/step - loss: 0.4992 - accuracy: 0.7883
# Epoch 31/50
# 27/27 [==============================] - 0s 520us/step - loss: 0.4968 - accuracy: 0.7883
# Epoch 32/50
# 27/27 [==============================] - 0s 531us/step - loss: 0.4946 - accuracy: 0.7895
# Epoch 33/50
# 27/27 [==============================] - 0s 469us/step - loss: 0.4922 - accuracy: 0.7907
# Epoch 34/50
# 27/27 [==============================] - 0s 504us/step - loss: 0.4903 - accuracy: 0.7931
# Epoch 35/50
# 27/27 [==============================] - 0s 645us/step - loss: 0.4880 - accuracy: 0.7895
# Epoch 36/50
# 27/27 [==============================] - 0s 467us/step - loss: 0.4863 - accuracy: 0.7931
# Epoch 37/50
# 27/27 [==============================] - 0s 522us/step - loss: 0.4845 - accuracy: 0.7943
# Epoch 38/50
# 27/27 [==============================] - 0s 491us/step - loss: 0.4833 - accuracy: 0.7931
# Epoch 39/50
# 27/27 [==============================] - 0s 487us/step - loss: 0.4817 - accuracy: 0.7931
# Epoch 40/50
# 27/27 [==============================] - 0s 526us/step - loss: 0.4800 - accuracy: 0.7943
# Epoch 41/50
# 27/27 [==============================] - 0s 466us/step - loss: 0.4785 - accuracy: 0.7967
# Epoch 42/50
# 27/27 [==============================] - 0s 518us/step - loss: 0.4771 - accuracy: 0.7955
# Epoch 43/50
# 27/27 [==============================] - 0s 483us/step - loss: 0.4757 - accuracy: 0.7955
# Epoch 44/50
# 27/27 [==============================] - 0s 517us/step - loss: 0.4744 - accuracy: 0.7955
# Epoch 45/50
# 27/27 [==============================] - 0s 495us/step - loss: 0.4734 - accuracy: 0.7978
# Epoch 46/50
# 27/27 [==============================] - 0s 536us/step - loss: 0.4731 - accuracy: 0.7955
# Epoch 47/50
# 27/27 [==============================] - 0s 494us/step - loss: 0.4712 - accuracy: 0.7919
# Epoch 48/50
# 27/27 [==============================] - 0s 484us/step - loss: 0.4701 - accuracy: 0.7931
# Epoch 49/50
# 27/27 [==============================] - 0s 505us/step - loss: 0.4689 - accuracy: 0.7978
# Epoch 50/50
# 27/27 [==============================] - 0s 483us/step - loss: 0.4678 - accuracy: 0.7978

# %%
y_pred = np.rint(model.predict(X_test).flatten())
print(metrics.accuracy_score(y_test, y_pred))
# Out:
# 7/7 [==============================] - 0s 524us/step
# 0.7894736842105263
